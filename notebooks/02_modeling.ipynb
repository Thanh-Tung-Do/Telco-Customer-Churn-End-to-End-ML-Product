# %% [markdown]
# # Customer Churn — Modeling
# **Kaggle Playground Series S6E3**
#
# ### What this notebook does
# 1. Builds a reusable preprocessing pipeline
# 2. Trains three models: baseline LR → cost-sensitive LR → XGBoost
# 3. Evaluates each on ROC-AUC (competition metric) and business cost
# 4. Generates a Kaggle submission from the best model
# 5. Saves the best model as a `.pkl` file

# %%
import sys
sys.path.append('..')

import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import joblib

from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.model_selection import StratifiedKFold, cross_val_score
from sklearn.metrics import roc_auc_score
from xgboost import XGBClassifier

from src.preprocessing import load_data, encode_target, build_preprocessor, ALL_FEATURE_COLS
from src.model_utils import evaluate, plot_roc_curves, plot_confusion_matrix, find_optimal_threshold, make_submission

plt.style.use('seaborn-v0_8-whitegrid')
RANDOM_STATE = 42

TRAIN_PATH  = '../data/raw/train.csv'
TEST_PATH   = '../data/raw/test.csv'
MODEL_DIR   = '../src/models/'
SUB_PATH    = '../data/processed/submission.csv'

# %% [markdown]
# ## 1. Load & Prepare Data

# %%
train, test = load_data(TRAIN_PATH, TEST_PATH)

X = train[ALL_FEATURE_COLS]
y = encode_target(train['Churn'])
X_test = test[ALL_FEATURE_COLS]
test_ids = test['id']

print(f'X train : {X.shape}')
print(f'X test  : {X_test.shape}')
print(f'Churn rate: {y.mean():.3f}')
# Out:
# X train : (594194, 19)
# X test  : (254655, 19)
# Churn rate: 0.225

# %% [markdown]
# ## 2. Cross-Validation Setup
#
# Using **5-fold Stratified K-Fold** to preserve class ratios across folds. Each model is evaluated by CV ROC-AUC before we commit to full training.

# %%
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=RANDOM_STATE)

def cv_auc(pipeline):
    scores = cross_val_score(pipeline, X, y, cv=cv,
                             scoring='roc_auc', n_jobs=-1)
    print(f'  CV AUC: {scores.mean():.4f} ± {scores.std():.4f}')
    return scores

# %% [markdown]
# ## 3. Model 1 — Baseline Logistic Regression
#
# Logistic regression is interpretable and gives us a meaningful baseline with pseudo R² and coefficient-level insights.

# %%
preprocessor = build_preprocessor()

lr_baseline = Pipeline([
    ('prep', preprocessor),
    ('clf', LogisticRegression(max_iter=1000, random_state=RANDOM_STATE, solver='lbfgs'))
])

print('Logistic Regression (baseline):')
lr_baseline_scores = cv_auc(lr_baseline)
# Out:
# Logistic Regression (baseline):
#   CV AUC: 0.9051 ± 0.0010

# %%
# Fit on full training set for inspection
lr_baseline.fit(X, y)

# Pseudo R² (McFadden's) and AIC/BIC via statsmodels
import statsmodels.api as sm

X_transformed = lr_baseline.named_steps['prep'].transform(X)
X_sm = sm.add_constant(X_transformed)
logit_model = sm.Logit(y, X_sm)
result = logit_model.fit(maxiter=300, disp=False)

print(f"Pseudo R² (McFadden's): {result.prsquared:.4f}")
print(f"AIC                   : {result.aic:.2f}")
print(f"BIC                   : {result.bic:.2f}")
# Out:
# Pseudo R² (McFadden's): 0.4063
# AIC                   : 376403.87
# BIC                   : 376629.77

# %% [markdown]
# ## 4. Model 2 — Cost-Sensitive Logistic Regression
#
# `class_weight='balanced'` penalises misclassifying the minority class (churners) more heavily, which aligns the model with the business objective: missing a churner is more expensive than a false alarm.

# %%
preprocessor2 = build_preprocessor()

lr_balanced = Pipeline([
    ('prep', preprocessor2),
    ('clf', LogisticRegression(
        max_iter=1000,
        class_weight='balanced',
        random_state=RANDOM_STATE,
        solver='lbfgs'
    ))
])

print('Logistic Regression (cost-sensitive):')
lr_balanced_scores = cv_auc(lr_balanced)
lr_balanced.fit(X, y)
# Out:
# Logistic Regression (cost-sensitive):
#   CV AUC: 0.9049 ± 0.0010
# Pipeline(steps=[('prep',
#                  ColumnTransformer(transformers=[('binary',
#                                                   Pipeline(steps=[('enc',
#                                                                    OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                                   unknown_value=-1))]),
#                                                   ['gender', 'Partner',
#                                                    'Dependents', 'PhoneService',
#                                                    'PaperlessBilling']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('enc',
#                                                                    OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                                   unknown_value=-1))]),
#                                                   ['MultipleLines',
#                                                    'In...
#                                                    'OnlineBackup',
#                                                    'DeviceProtection',
#                                                    'TechSupport', 'StreamingTV',
#                                                    'StreamingMovies',
#                                                    'Contract',
#                                                    'PaymentMethod']),
#                                                  ('num',
#                                                   Pipeline(steps=[('impute',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scale',
#                                                                    StandardScaler())]),
#                                                   ['SeniorCitizen', 'tenure',
#                                                    'MonthlyCharges',
#                                                    'TotalCharges'])])),
#                 ('clf',
#                  LogisticRegression(class_weight='balanced', max_iter=1000,
#                                     random_state=42))])

# %% [markdown]
# ## 5. Model 3 — XGBoost
#
# Gradient boosting handles the feature interactions (e.g. high monthly charges + month-to-month contract) that logistic regression misses. We use `scale_pos_weight` to compensate for class imbalance.

# %%
neg_pos_ratio = (y == 0).sum() / (y == 1).sum()
print(f'scale_pos_weight = {neg_pos_ratio:.2f}')

preprocessor3 = build_preprocessor()

xgb = Pipeline([
    ('prep', preprocessor3),
    ('clf', XGBClassifier(
        n_estimators=500,
        learning_rate=0.05,
        max_depth=5,
        subsample=0.8,
        colsample_bytree=0.8,
        scale_pos_weight=neg_pos_ratio,
        eval_metric='auc',
        random_state=RANDOM_STATE,
        n_jobs=-1,
        verbosity=0
    ))
])

print('XGBoost:')
xgb_scores = cv_auc(xgb)
xgb.fit(X, y)
# Out:
# scale_pos_weight = 3.44
# XGBoost:
#   CV AUC: 0.9161 ± 0.0009
# Pipeline(steps=[('prep',
#                  ColumnTransformer(transformers=[('binary',
#                                                   Pipeline(steps=[('enc',
#                                                                    OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                                   unknown_value=-1))]),
#                                                   ['gender', 'Partner',
#                                                    'Dependents', 'PhoneService',
#                                                    'PaperlessBilling']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('enc',
#                                                                    OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                                   unknown_value=-1))]),
#                                                   ['MultipleLines',
#                                                    'In...
#                                feature_types=None, feature_weights=None,
#                                gamma=None, grow_policy=None,
#                                importance_type=None,
#                                interaction_constraints=None, learning_rate=0.05,
#                                max_bin=None, max_cat_threshold=None,
#                                max_cat_to_onehot=None, max_delta_step=None,
#                                max_depth=5, max_leaves=None,
#                                min_child_weight=None, missing=nan,
#                                monotone_constraints=None, multi_strategy=None,
#                                n_estimators=500, n_jobs=-1,
#                                num_parallel_tree=None, ...))])

# %% [markdown]
# ## 6. Model Comparison

# %%
results = pd.DataFrame({
    'Model': ['LR Baseline', 'LR Cost-Sensitive', 'XGBoost'],
    'CV AUC Mean': [
        lr_baseline_scores.mean(),
        lr_balanced_scores.mean(),
        xgb_scores.mean()
    ],
    'CV AUC Std': [
        lr_baseline_scores.std(),
        lr_balanced_scores.std(),
        xgb_scores.std()
    ]
})

results = results.sort_values('CV AUC Mean', ascending=False).reset_index(drop=True)
print(results.to_string(index=False))
# Out:
#             Model  CV AUC Mean  CV AUC Std
#           XGBoost     0.916079    0.000930
#       LR Baseline     0.905106    0.001002
# LR Cost-Sensitive     0.904928    0.001036

# %% [markdown]
# ## 7. ROC Curves & Confusion Matrix (Validation Fold)
#
# We'll use one held-out fold to generate probability estimates for visual comparison.

# %%
from sklearn.model_selection import train_test_split

X_tr, X_val, y_tr, y_val = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=RANDOM_STATE
)

# Fit on train split, predict on val split
models_val = {}
for name, pipe in [
    ('LR Baseline',       lr_baseline),
    ('LR Cost-Sensitive', lr_balanced),
    ('XGBoost',           xgb)
]:
    pipe.fit(X_tr, y_tr)
    models_val[name] = pipe.predict_proba(X_val)[:, 1]

fig = plot_roc_curves(models_val, y_val)
fig.savefig('../data/processed/fig_roc_curves.png', dpi=150)
plt.show()

# %%
# Full evaluation with cost analysis for each model
for name, proba in models_val.items():
    evaluate(y_val, proba, threshold=0.5, model_name=name)
# Out:
# ==================================================
#   LR Baseline
# ==================================================
# ROC-AUC : 0.9057
# Threshold: 0.5
#               precision    recall  f1-score   support
#
#     No Churn       0.90      0.91      0.91     92076
#        Churn       0.68      0.65      0.67     26763
#
#     accuracy                           0.85    118839
#    macro avg       0.79      0.78      0.79    118839
# weighted avg       0.85      0.85      0.85    118839
#
# -- Cost Analysis (threshold=0.5) --
#   True Positives  (retained churners) : 17,459  → saves $ 5,237,700
#   False Positives (wasted offers)      :  8,237  → costs $   411,850
#   False Negatives (missed churners)    :  9,304  → costs $ 4,652,000
#   Net business impact                  :         $  +173,850
#
# ==================================================
#   LR Cost-Sensitive
# ==================================================
# ROC-AUC : 0.9055
# Threshold: 0.5
#               precision    recall  f1-score   support
#
#     No Churn       0.96      0.78      0.86     92076
#        Churn       0.54      0.88      0.67     26763
#
#     accuracy                           0.80    118839
#    macro avg       0.75      0.83      0.76    118839
# weighted avg       0.86      0.80      0.81    118839
#
# -- Cost Analysis (threshold=0.5) --
#   True Positives  (retained churners) : 23,567  → saves $ 7,070,100
#   False Positives (wasted offers)      : 20,458  → costs $ 1,022,900
#   False Negatives (missed churners)    :  3,196  → costs $ 1,598,000
#   Net business impact                  :         $+4,449,200
#
# ==================================================
#   XGBoost
# ==================================================
# ROC-AUC : 0.9164
# Threshold: 0.5
#               precision    recall  f1-score   support
#
#     No Churn       0.96      0.80      0.87     92076
#        Churn       0.56      0.88      0.68     26763
#
#     accuracy                           0.82    118839
#    macro avg       0.76      0.84      0.78    118839
# weighted avg       0.87      0.82      0.83    118839
#
# -- Cost Analysis (threshold=0.5) --
#   True Positives  (retained churners) : 23,547  → saves $ 7,064,100
#   False Positives (wasted offers)      : 18,499  → costs $   924,950
#   False Negatives (missed churners)    :  3,216  → costs $ 1,608,000
#   Net business impact                  :         $+4,531,150

# %% [markdown]
# ## 7b. Business Cost — Normalised per 10,000 Customers
#
# ROC-AUC tells us about rank-ordering quality. This table translates model performance into dollar terms, normalised to a common base of 10,000 customers so models are directly comparable regardless of validation set size.
#
# Cost assumptions (see `src/model_utils.py`): **missed churner = $500** (lost CLV), **wasted offer = $50** (discount + agent time), **successful retention = $300** (net saving after offer cost).

# %%
from src.model_utils import business_cost_table

cost_df = business_cost_table(models_val, y_val, threshold=0.5, per_n=10_000)
display(cost_df)
# Out:
#                Model  Retained / 10,000  Wasted offers / 10,000  \
# 0        LR Baseline               1469                     693
# 1  LR Cost-Sensitive               1983                    1721
# 2            XGBoost               1981                    1557
#
#    Missed churners / 10,000 Net value / 10,000 vs. Baseline
# 0                       783           $+14,629          $+0
# 1                       269          $+374,389    $+359,760
# 2                       271          $+381,285    $+366,656

# %% [markdown]
# ## 8. Optimal Threshold (Business Cost)
#
# The default 0.5 threshold is rarely optimal. We sweep thresholds to find the one that minimises the total cost of missed churners + wasted retention offers.

# %%
best_model_name = results.iloc[0]['Model']
best_proba_val = models_val[best_model_name]

optimal_t = find_optimal_threshold(y_val, best_proba_val)
print(f'Optimal threshold for {best_model_name}: {optimal_t:.2f}')

evaluate(y_val, best_proba_val, threshold=optimal_t, model_name=f'{best_model_name} (optimal threshold)')
# Out:
# Optimal threshold for XGBoost: 0.28
#
# ==================================================
#   XGBoost (optimal threshold)
# ==================================================
# ROC-AUC : 0.9164
# Threshold: 0.28
#               precision    recall  f1-score   support
#
#     No Churn       0.98      0.69      0.81     92076
#        Churn       0.47      0.95      0.63     26763
#
#     accuracy                           0.75    118839
#    macro avg       0.73      0.82      0.72    118839
# weighted avg       0.87      0.75      0.77    118839
#
# -- Cost Analysis (threshold=0.28) --
#   True Positives  (retained churners) : 25,494  → saves $ 7,648,200
#   False Positives (wasted offers)      : 28,651  → costs $ 1,432,550
#   False Negatives (missed churners)    :  1,269  → costs $   634,500
#   Net business impact                  :         $+5,581,150
# 0.916412132186097

# %% [markdown]
# ## 8b. Threshold Tradeoff — Precision / Recall & Business Value
#
# The decision threshold is a **business parameter**, not a modelling parameter. As we lower the threshold we catch more churners (higher recall) at the cost of more false alarms (lower precision). The right panel shows this directly in dollar terms: what is the net business value at each threshold, and where is it maximised?

# %%
from src.model_utils import plot_threshold_analysis

fig = plot_threshold_analysis(y_val, best_proba_val, model_name=best_model_name)
fig.savefig('../data/processed/fig_threshold_analysis.png', dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 9. Feature Importance (XGBoost)

# %%
from src.preprocessing import ALL_FEATURE_COLS

feature_names = ALL_FEATURE_COLS
importances = xgb.named_steps['clf'].feature_importances_

feat_imp = (pd.DataFrame({'feature': feature_names, 'importance': importances})
              .sort_values('importance', ascending=False)
              .head(15))

fig, ax = plt.subplots(figsize=(8, 5))
sns.barplot(data=feat_imp, x='importance', y='feature', ax=ax, palette='viridis')
ax.set_title('XGBoost — Top 15 Feature Importances')
ax.set_xlabel('Importance Score')
ax.set_ylabel('')
plt.tight_layout()
plt.savefig('../data/processed/fig_feature_importance.png', dpi=150)
plt.show()

# %% [markdown]
# ## 10. SHAP Explainability — Why Does the Model Flag This Customer?
#
# Feature importances tell us which variables the model uses most. SHAP values tell us **by how much** each feature pushes an individual prediction up or down from the base rate — making the model auditable for stakeholders.
#
# - **Beeswarm plot**: global view — each dot is one customer; colour = feature value; x-position = impact on churn probability
# - **Waterfall plot**: single-customer explanation for the highest-risk customer in the validation sample

# %%
import shap
from src.preprocessing import get_feature_names

# Use the pipeline fitted on X_tr (from the val split in section 7)
clf_shap = xgb.named_steps['clf']
prep_shap = xgb.named_steps['prep']
feature_names = get_feature_names(prep_shap)

SHAP_SAMPLE = 2000
X_val_t = prep_shap.transform(X_val.iloc[:SHAP_SAMPLE])

explainer = shap.TreeExplainer(clf_shap)
shap_exp = explainer(X_val_t)
shap_exp.feature_names = feature_names

# Beeswarm: global feature impact with directionality
shap.summary_plot(shap_exp.values, X_val_t, feature_names=feature_names, show=False)
plt.tight_layout()
plt.savefig('../data/processed/fig_shap_summary.png', dpi=150, bbox_inches='tight')
plt.show()

# %%
# Waterfall for the single highest-risk customer in the sample
high_risk_idx = int(np.argmax(models_val['XGBoost'][:SHAP_SAMPLE]))
shap.plots.waterfall(shap_exp[high_risk_idx], max_display=12, show=False)
plt.title(
    f"SHAP Waterfall — Highest-Risk Customer  "
    f"(predicted p = {models_val['XGBoost'][high_risk_idx]:.2f})"
)
plt.tight_layout()
plt.savefig('../data/processed/fig_shap_waterfall.png', dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 10. Generate Kaggle Submission
#
# Refit the best model on the full training set (no val holdout) and predict probabilities on the test set.

# %%
# Map model name back to pipeline
name_to_pipe = {
    'LR Baseline':       lr_baseline,
    'LR Cost-Sensitive': lr_balanced,
    'XGBoost':           xgb,
}

best_pipe = name_to_pipe[best_model_name]

# Final fit on all training data
best_pipe.fit(X, y)

test_proba = best_pipe.predict_proba(X_test)[:, 1]
make_submission(test_ids, test_proba, SUB_PATH)

pd.read_csv(SUB_PATH).head()
# Out:
# Submission saved → ../data/processed/submission.csv  (254,655 rows)
#        id     Churn
# 0  594194  0.200660
# 1  594195  0.001799
# 2  594196  0.276222
# 3  594197  0.010886
# 4  594198  0.774477

# %% [markdown]
# ## 11. Save Best Model

# %%
import os
os.makedirs(MODEL_DIR, exist_ok=True)

model_filename = f"{MODEL_DIR}{best_model_name.lower().replace(' ', '_')}_pipeline.pkl"
joblib.dump(best_pipe, model_filename)
print(f'Model saved → {model_filename}')
# Out:
# Model saved → ../src/models/xgboost_pipeline.pkl

# %% [markdown]
# ## Summary
#
# | Model | CV ROC-AUC | Strengths |
# |---|---|---|
# | LR Baseline | see above | Interpretable coefficients, fast |
# | LR Cost-Sensitive | see above | Better recall on churners |
# | XGBoost | see above | Captures non-linear feature interactions |
#
# **Key modeling decisions**:
# - Stratified K-Fold preserves class ratios — more reliable AUC estimates than random splits
# - `class_weight='balanced'` / `scale_pos_weight` aligns training loss with business cost structure
# - Threshold optimisation (Section 8) shifts the operating point from ROC-AUC maximisation to cost minimisation — a meaningful distinction for deployment
# - Submission uses probability scores (not hard labels) as required by the Kaggle competition
